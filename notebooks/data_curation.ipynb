# %%
import pandas as pd

# %%
filepath = "../data/CHEMBL217_raw_data.csv"
df = pd.read_csv(filepath, sep=";")
df
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0             CHEMBL7927      FAUC 113                 NaN            326.83
# 1          CHEMBL2028019   CARIPRAZINE                 4.0            427.42
# 2          CHEMBL2028019   CARIPRAZINE                 4.0            427.42
# 3          CHEMBL2028019   CARIPRAZINE                 4.0            427.42
# 4             CHEMBL1112  ARIPIPRAZOLE                 4.0            448.39
# ...                  ...           ...                 ...               ...
# 32474      CHEMBL5770250           NaN                 NaN            493.57
# 32475      CHEMBL5839093           NaN                 NaN            518.58
# 32476      CHEMBL5923691           NaN                 NaN            500.59
# 32477      CHEMBL4470996           NaN                 NaN            367.47
# 32478      CHEMBL4538239           NaN                 NaN            351.41
#
#        #RO5 Violations  AlogP  Compound Key  \
# 0                  0.0   3.31      FAUC 113
# 1                  0.0   4.34            32
# 2                  0.0   4.34            32
# 3                  0.0   4.34            32
# 4                  0.0   4.86            31
# ...                ...    ...           ...
# 32474              0.0   3.31    BDBM593886
# 32475              1.0   3.01    BDBM593889
# 32476              1.0   2.72    BDBM593893
# 32477              0.0   3.13  BDBM50528025
# 32478              0.0   1.79  BDBM50528049
#
#                                                   Smiles     Standard Type  \
# 0                   Clc1ccc(N2CCN(Cc3cnn4ccccc34)CC2)cc1                Ki
# 1      CN(C)C(=O)N[C@H]1CC[C@H](CCN2CCN(c3cccc(Cl)c3C...  deltalog(Tau/KA)
# 2      CN(C)C(=O)N[C@H]1CC[C@H](CCN2CCN(c3cccc(Cl)c3C...  deltalog(Tau/KA)
# 3      CN(C)C(=O)N[C@H]1CC[C@H](CCN2CCN(c3cccc(Cl)c3C...  deltalog(Tau/KA)
# 4        O=C1CCc2ccc(OCCCCN3CCN(c4cccc(Cl)c4Cl)CC3)cc2N1              T1/2
# ...                                                  ...               ...
# 32474  Cn1cc(CC(=O)NC2CCC(CCN3CCc4ccc(OCC(F)F)nc4CC3)...             k_off
# 32475  Cn1ncc(CC(=O)N[C@H]2CC[C@](F)(CCN3CCc4nc(OCC(F...             k_off
# 32476  Cn1ncc(CC(=O)N[C@H]2CC[C@](F)(CCN3CCc4nc(OCC(F...                Ki
# 32477            O=C(c1cc2ccccc2s1)N1CCN(CCOc2cccnc2)CC1              IC50
# 32478         O=C(c1n[nH]c2ccccc12)N1CCN(CCOc2cccnc2)CC1             k_off
#
#       Standard Relation  ...  Document ChEMBL ID Source ID  \
# 0                   '='  ...       CHEMBL1138042         1
# 1                   '='  ...       CHEMBL4028823         1
# 2                   '='  ...       CHEMBL4028823         1
# 3                   '='  ...       CHEMBL4028823         1
# 4                   '='  ...       CHEMBL4028823         1
# ...                 ...  ...                 ...       ...
# 32474               '='  ...       CHEMBL5729591        37
# 32475               '='  ...       CHEMBL5729591        37
# 32476               '='  ...       CHEMBL5729591        37
# 32477               '='  ...       CHEMBL5729677        37
# 32478               '='  ...       CHEMBL5729677        37
#
#                       Source Description      Document Journal Document Year  \
# 0                  Scientific Literature            J Med Chem        2006.0
# 1                  Scientific Literature  Bioorg Med Chem Lett        2017.0
# 2                  Scientific Literature  Bioorg Med Chem Lett        2017.0
# 3                  Scientific Literature  Bioorg Med Chem Lett        2017.0
# 4                  Scientific Literature  Bioorg Med Chem Lett        2017.0
# ...                                  ...                   ...           ...
# 32474  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32475  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32476  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32477  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32478  BindingDB Patent Bioactivity Data                   NaN        2023.0
#
#       Cell ChEMBL ID  Properties  Action Type  Standard Text Value   Value
# 0      CHEMBL3308072         NaN          NaN                  NaN  4300.0
# 1                NaN         NaN          NaN                  NaN     0.7
# 2                NaN         NaN          NaN                  NaN     0.2
# 3                NaN         NaN          NaN                  NaN     0.3
# 4                NaN         NaN          NaN                  NaN     4.9
# ...              ...         ...          ...                  ...     ...
# 32474            NaN         NaN          NaN                  NaN     NaN
# 32475            NaN         NaN          NaN                  NaN     NaN
# 32476            NaN         NaN          NaN                  NaN  1900.0
# 32477            NaN         NaN          NaN                  NaN  2100.0
# 32478            NaN         NaN          NaN                  NaN     NaN
#
# [32479 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties',
#        'Action Type', 'Standard Text Value', 'Value'],
#       dtype='str')

# %%
df_pchembl = df[df["pChEMBL Value"].notnull()]
df_pchembl
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0             CHEMBL7927      FAUC 113                 NaN            326.83
# 5          CHEMBL1078207           NaN                 NaN            458.59
# 7           CHEMBL231546           NaN                 NaN            505.87
# 8           CHEMBL231431           NaN                 NaN            444.96
# 9           CHEMBL231333           NaN                 NaN            358.51
# ...                  ...           ...                 ...               ...
# 32468      CHEMBL5825727           NaN                 NaN            529.65
# 32469      CHEMBL5993200           NaN                 NaN            488.60
# 32471      CHEMBL5987260           NaN                 NaN            517.59
# 32476      CHEMBL5923691           NaN                 NaN            500.59
# 32477      CHEMBL4470996           NaN                 NaN            367.47
#
#        #RO5 Violations  AlogP  Compound Key  \
# 0                  0.0   3.31      FAUC 113
# 5                  0.0   4.48            24
# 7                  2.0   5.60            21
# 8                  0.0   4.98            13
# 9                  0.0   3.82             9
# ...                ...    ...           ...
# 32468              1.0   3.56    BDBM593851
# 32469              1.0   5.06    BDBM593853
# 32471              1.0   3.67    BDBM593874
# 32476              1.0   2.72    BDBM593893
# 32477              0.0   3.13  BDBM50528025
#
#                                                   Smiles Standard Type  \
# 0                   Clc1ccc(N2CCN(Cc3cnn4ccccc34)CC2)cc1            Ki
# 5      O=S(=O)(Nc1ccc2c(c1)CCN(Cc1cc[nH]n1)CC2)c1ccc(...            Ki
# 7      CN1CCc2cc(Br)c(NS(=O)(=O)c3ccc(-c4ccc(Cl)cc4)c...            Ki
# 8      CN1CCc2ccc(NS(=O)(=O)c3ccc(-c4ccc(F)c(Cl)c4)cc...            Ki
# 9            CCCCc1ccc(S(=O)(=O)Nc2ccc3c(c2)CN(C)CC3)cc1            Ki
# ...                                                  ...           ...
# 32468  Cc1ncc(CC(=O)NC2CC3CCC(C2)N3CCN2CCc3sc(OCC(F)(...            Ki
# 32469  Cc1ncccc1C(=O)N[C@H]1CC[C@H](CCN2CCc3ccc(CCC(F...            Ki
# 32471  Cn1ncc(CC(=O)N[C@H]2CC[C@H](CCN3CCc4nc(OCC(F)(...            Ki
# 32476  Cn1ncc(CC(=O)N[C@H]2CC[C@](F)(CCN3CCc4nc(OCC(F...            Ki
# 32477            O=C(c1cc2ccccc2s1)N1CCN(CCOc2cccnc2)CC1          IC50
#
#       Standard Relation  ...  Document ChEMBL ID Source ID  \
# 0                   '='  ...       CHEMBL1138042         1
# 5                   '='  ...       CHEMBL1154336         1
# 7                   '='  ...       CHEMBL1143778         1
# 8                   '='  ...       CHEMBL1143778         1
# 9                   '='  ...       CHEMBL1143778         1
# ...                 ...  ...                 ...       ...
# 32468               '='  ...       CHEMBL5729591        37
# 32469               '='  ...       CHEMBL5729591        37
# 32471               '='  ...       CHEMBL5729591        37
# 32476               '='  ...       CHEMBL5729591        37
# 32477               '='  ...       CHEMBL5729677        37
#
#                       Source Description      Document Journal Document Year  \
# 0                  Scientific Literature            J Med Chem        2006.0
# 5                  Scientific Literature  Bioorg Med Chem Lett        2009.0
# 7                  Scientific Literature  Bioorg Med Chem Lett        2007.0
# 8                  Scientific Literature  Bioorg Med Chem Lett        2007.0
# 9                  Scientific Literature  Bioorg Med Chem Lett        2007.0
# ...                                  ...                   ...           ...
# 32468  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32469  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32471  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32476  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32477  BindingDB Patent Bioactivity Data                   NaN        2023.0
#
#       Cell ChEMBL ID  Properties  Action Type  Standard Text Value   Value
# 0      CHEMBL3308072         NaN          NaN                  NaN  4300.0
# 5                NaN         NaN          NaN                  NaN     6.2
# 7      CHEMBL3308072         NaN          NaN                  NaN    -7.2
# 8      CHEMBL3308072         NaN          NaN                  NaN    -7.3
# 9      CHEMBL3308072         NaN          NaN                  NaN    -6.4
# ...              ...         ...          ...                  ...     ...
# 32468            NaN         NaN          NaN                  NaN   300.0
# 32469            NaN         NaN          NaN                  NaN   920.0
# 32471            NaN         NaN          NaN                  NaN  2000.0
# 32476            NaN         NaN          NaN                  NaN  1900.0
# 32477            NaN         NaN          NaN                  NaN  2100.0
#
# [15052 rows x 48 columns]

# %%
df_pchembl[["pChEMBL Value"]]
# Out:
#        pChEMBL Value
# 0               5.37
# 5               6.20
# 7               7.20
# 8               7.30
# 9               6.40
# ...              ...
# 32468           6.52
# 32469           6.04
# 32471           5.70
# 32476           5.72
# 32477           5.68
#
# [15052 rows x 1 columns]

# %%
df[df["Target Organism"] == "Homo sapiens"]
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0             CHEMBL7927      FAUC 113                 NaN            326.83
# 1          CHEMBL2028019   CARIPRAZINE                 4.0            427.42
# 2          CHEMBL2028019   CARIPRAZINE                 4.0            427.42
# 3          CHEMBL2028019   CARIPRAZINE                 4.0            427.42
# 4             CHEMBL1112  ARIPIPRAZOLE                 4.0            448.39
# ...                  ...           ...                 ...               ...
# 32474      CHEMBL5770250           NaN                 NaN            493.57
# 32475      CHEMBL5839093           NaN                 NaN            518.58
# 32476      CHEMBL5923691           NaN                 NaN            500.59
# 32477      CHEMBL4470996           NaN                 NaN            367.47
# 32478      CHEMBL4538239           NaN                 NaN            351.41
#
#        #RO5 Violations  AlogP  Compound Key  \
# 0                  0.0   3.31      FAUC 113
# 1                  0.0   4.34            32
# 2                  0.0   4.34            32
# 3                  0.0   4.34            32
# 4                  0.0   4.86            31
# ...                ...    ...           ...
# 32474              0.0   3.31    BDBM593886
# 32475              1.0   3.01    BDBM593889
# 32476              1.0   2.72    BDBM593893
# 32477              0.0   3.13  BDBM50528025
# 32478              0.0   1.79  BDBM50528049
#
#                                                   Smiles     Standard Type  \
# 0                   Clc1ccc(N2CCN(Cc3cnn4ccccc34)CC2)cc1                Ki
# 1      CN(C)C(=O)N[C@H]1CC[C@H](CCN2CCN(c3cccc(Cl)c3C...  deltalog(Tau/KA)
# 2      CN(C)C(=O)N[C@H]1CC[C@H](CCN2CCN(c3cccc(Cl)c3C...  deltalog(Tau/KA)
# 3      CN(C)C(=O)N[C@H]1CC[C@H](CCN2CCN(c3cccc(Cl)c3C...  deltalog(Tau/KA)
# 4        O=C1CCc2ccc(OCCCCN3CCN(c4cccc(Cl)c4Cl)CC3)cc2N1              T1/2
# ...                                                  ...               ...
# 32474  Cn1cc(CC(=O)NC2CCC(CCN3CCc4ccc(OCC(F)F)nc4CC3)...             k_off
# 32475  Cn1ncc(CC(=O)N[C@H]2CC[C@](F)(CCN3CCc4nc(OCC(F...             k_off
# 32476  Cn1ncc(CC(=O)N[C@H]2CC[C@](F)(CCN3CCc4nc(OCC(F...                Ki
# 32477            O=C(c1cc2ccccc2s1)N1CCN(CCOc2cccnc2)CC1              IC50
# 32478         O=C(c1n[nH]c2ccccc12)N1CCN(CCOc2cccnc2)CC1             k_off
#
#       Standard Relation  ...  Document ChEMBL ID Source ID  \
# 0                   '='  ...       CHEMBL1138042         1
# 1                   '='  ...       CHEMBL4028823         1
# 2                   '='  ...       CHEMBL4028823         1
# 3                   '='  ...       CHEMBL4028823         1
# 4                   '='  ...       CHEMBL4028823         1
# ...                 ...  ...                 ...       ...
# 32474               '='  ...       CHEMBL5729591        37
# 32475               '='  ...       CHEMBL5729591        37
# 32476               '='  ...       CHEMBL5729591        37
# 32477               '='  ...       CHEMBL5729677        37
# 32478               '='  ...       CHEMBL5729677        37
#
#                       Source Description      Document Journal Document Year  \
# 0                  Scientific Literature            J Med Chem        2006.0
# 1                  Scientific Literature  Bioorg Med Chem Lett        2017.0
# 2                  Scientific Literature  Bioorg Med Chem Lett        2017.0
# 3                  Scientific Literature  Bioorg Med Chem Lett        2017.0
# 4                  Scientific Literature  Bioorg Med Chem Lett        2017.0
# ...                                  ...                   ...           ...
# 32474  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32475  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32476  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32477  BindingDB Patent Bioactivity Data                   NaN        2023.0
# 32478  BindingDB Patent Bioactivity Data                   NaN        2023.0
#
#       Cell ChEMBL ID  Properties  Action Type  Standard Text Value   Value
# 0      CHEMBL3308072         NaN          NaN                  NaN  4300.0
# 1                NaN         NaN          NaN                  NaN     0.7
# 2                NaN         NaN          NaN                  NaN     0.2
# 3                NaN         NaN          NaN                  NaN     0.3
# 4                NaN         NaN          NaN                  NaN     4.9
# ...              ...         ...          ...                  ...     ...
# 32474            NaN         NaN          NaN                  NaN     NaN
# 32475            NaN         NaN          NaN                  NaN     NaN
# 32476            NaN         NaN          NaN                  NaN  1900.0
# 32477            NaN         NaN          NaN                  NaN  2100.0
# 32478            NaN         NaN          NaN                  NaN     NaN
#
# [32479 rows x 48 columns]

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import PandasTools

def identify_duplicates(df, smiles_column):
    def standardize_smiles(smiles):
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return None
            return Chem.MolToSmiles(mol, canonical=True)
        except:
            return None

    def calculate_inchi_key(smiles):
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return None
            return Chem.MolToInchiKey(mol)
        except:
            return None

    df_analysis = df.copy()
    df_analysis["canonical_smiles"] = df_analysis[smiles_column].apply(standardize_smiles)
    df_analysis["inchi_key"] = df_analysis["canonical_smiles"].apply(calculate_inchi_key)
    df_analysis["is_valid"] = df_analysis["canonical_smiles"].notna()
    df_analysis["is_duplicate"] = df_analysis["inchi_key"].duplicated(keep="first")
    df_analysis["duplicate_group"] = df_analysis.groupby("inchi_key").ngroup()
    duplicate_counts = df_analysis["inchi_key"].value_counts()
    df_analysis["occurrence_count"] = df_analysis["inchi_key"].map(duplicate_counts)

    return df_analysis

def get_duplicate_summary(df_analysis):
    summary = {
        "total_molecules": len(df_analysis),
        "invalid_smiles": (~df_analysis["is_valid"]).sum(),
        "unique_molecules": df_analysis["inchi_key"].nunique(),
        "duplicate_molecules": df_analysis["is_duplicate"].sum(),
        "molecules_with_duplicates": len(df_analysis[df_analysis["occurrence_count"] > 1]),
        "max_duplicates": df_analysis["occurrence_count"].max()
    }
    return summary

# %%
df_analyzed = identify_duplicates(df_pchembl, "Smiles")
df_analyzed
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0             CHEMBL7927      FAUC 113                 NaN            326.83
# 5          CHEMBL1078207           NaN                 NaN            458.59
# 7           CHEMBL231546           NaN                 NaN            505.87
# 8           CHEMBL231431           NaN                 NaN            444.96
# 9           CHEMBL231333           NaN                 NaN            358.51
# ...                  ...           ...                 ...               ...
# 32468      CHEMBL5825727           NaN                 NaN            529.65
# 32469      CHEMBL5993200           NaN                 NaN            488.60
# 32471      CHEMBL5987260           NaN                 NaN            517.59
# 32476      CHEMBL5923691           NaN                 NaN            500.59
# 32477      CHEMBL4470996           NaN                 NaN            367.47
#
#        #RO5 Violations  AlogP  Compound Key  \
# 0                  0.0   3.31      FAUC 113
# 5                  0.0   4.48            24
# 7                  2.0   5.60            21
# 8                  0.0   4.98            13
# 9                  0.0   3.82             9
# ...                ...    ...           ...
# 32468              1.0   3.56    BDBM593851
# 32469              1.0   5.06    BDBM593853
# 32471              1.0   3.67    BDBM593874
# 32476              1.0   2.72    BDBM593893
# 32477              0.0   3.13  BDBM50528025
#
#                                                   Smiles Standard Type  \
# 0                   Clc1ccc(N2CCN(Cc3cnn4ccccc34)CC2)cc1            Ki
# 5      O=S(=O)(Nc1ccc2c(c1)CCN(Cc1cc[nH]n1)CC2)c1ccc(...            Ki
# 7      CN1CCc2cc(Br)c(NS(=O)(=O)c3ccc(-c4ccc(Cl)cc4)c...            Ki
# 8      CN1CCc2ccc(NS(=O)(=O)c3ccc(-c4ccc(F)c(Cl)c4)cc...            Ki
# 9            CCCCc1ccc(S(=O)(=O)Nc2ccc3c(c2)CN(C)CC3)cc1            Ki
# ...                                                  ...           ...
# 32468  Cc1ncc(CC(=O)NC2CC3CCC(C2)N3CCN2CCc3sc(OCC(F)(...            Ki
# 32469  Cc1ncccc1C(=O)N[C@H]1CC[C@H](CCN2CCc3ccc(CCC(F...            Ki
# 32471  Cn1ncc(CC(=O)N[C@H]2CC[C@H](CCN3CCc4nc(OCC(F)(...            Ki
# 32476  Cn1ncc(CC(=O)N[C@H]2CC[C@](F)(CCN3CCc4nc(OCC(F...            Ki
# 32477            O=C(c1cc2ccccc2s1)N1CCN(CCOc2cccnc2)CC1          IC50
#
#       Standard Relation  ...  Properties Action Type  Standard Text Value  \
# 0                   '='  ...         NaN         NaN                  NaN
# 5                   '='  ...         NaN         NaN                  NaN
# 7                   '='  ...         NaN         NaN                  NaN
# 8                   '='  ...         NaN         NaN                  NaN
# 9                   '='  ...         NaN         NaN                  NaN
# ...                 ...  ...         ...         ...                  ...
# 32468               '='  ...         NaN         NaN                  NaN
# 32469               '='  ...         NaN         NaN                  NaN
# 32471               '='  ...         NaN         NaN                  NaN
# 32476               '='  ...         NaN         NaN                  NaN
# 32477               '='  ...         NaN         NaN                  NaN
#
#         Value                                   canonical_smiles  \
# 0      4300.0               Clc1ccc(N2CCN(Cc3cnn4ccccc34)CC2)cc1
# 5         6.2  O=S(=O)(Nc1ccc2c(c1)CCN(Cc1cc[nH]n1)CC2)c1ccc(...
# 7        -7.2  CN1CCc2cc(Br)c(NS(=O)(=O)c3ccc(-c4ccc(Cl)cc4)c...
# 8        -7.3  CN1CCc2ccc(NS(=O)(=O)c3ccc(-c4ccc(F)c(Cl)c4)cc...
# 9        -6.4        CCCCc1ccc(S(=O)(=O)Nc2ccc3c(c2)CN(C)CC3)cc1
# ...       ...                                                ...
# 32468   300.0  Cc1ncc(CC(=O)NC2CC3CCC(C2)N3CCN2CCc3sc(OCC(F)(...
# 32469   920.0  Cc1ncccc1C(=O)N[C@H]1CC[C@H](CCN2CCc3ccc(CCC(F...
# 32471  2000.0  Cn1ncc(CC(=O)N[C@H]2CC[C@H](CCN3CCc4nc(OCC(F)(...
# 32476  1900.0  Cn1ncc(CC(=O)N[C@H]2CC[C@](F)(CCN3CCc4nc(OCC(F...
# 32477  2100.0            O=C(c1cc2ccccc2s1)N1CCN(CCOc2cccnc2)CC1
#
#                          inchi_key  is_valid  is_duplicate  duplicate_group  \
# 0      XVPRVMIFXXOEFR-UHFFFAOYSA-N      True         False           8647.0
# 5      GSIRAOVJCFHRIN-UHFFFAOYSA-N      True         False           2241.0
# 7      QKCWJUZPSFBAKW-UHFFFAOYSA-N      True         False           6009.0
# 8      JYXPVNIIIHSWLZ-UHFFFAOYSA-N      True         False           3518.0
# 9      SJYYFOFHDQCHFJ-UHFFFAOYSA-N      True         False           6813.0
# ...                            ...       ...           ...              ...
# 32468  KKOVIGNMWZIDFQ-UHFFFAOYSA-N      True         False           3672.0
# 32469  IVGKEFCVDHKRFY-AQYVVDRMSA-N      True         False           3052.0
# 32471  AXWHEAPHZLQQJC-JCNLHEQBSA-N      True         False            381.0
# 32476  XUYHFDXRBDOBCI-FVUUGDKNSA-N      True         False           8636.0
# 32477  APECYVWEUYUQKJ-UHFFFAOYSA-N      True          True            245.0
#
#        occurrence_count
# 0                  16.0
# 5                   1.0
# 7                   1.0
# 8                   1.0
# 9                   1.0
# ...                 ...
# 32468               1.0
# 32469               1.0
# 32471               1.0
# 32476               1.0
# 32477               4.0
#
# [15052 rows x 54 columns]

# %%
summary = get_duplicate_summary(df_analyzed)
summary
# Out:
# {'total_molecules': 5529,
#  'invalid_smiles': np.int64(1),
#  'unique_molecules': 3421,
#  'duplicate_molecules': np.int64(2107),
#  'molecules_with_duplicates': 3394,
#  'max_duplicates': np.float64(32.0)}

# %%
import pandas as pd
import numpy as np

def process_duplicates(df, inchi_key_col, pchembl_col):
    """Process duplicates with different handling for zero-SD and non-zero-SD groups."""
    # Create working copy
    df_work = df.copy()

    # Calculate group statistics
    group_stats = df_work.groupby(inchi_key_col).agg({
        pchembl_col: ['count', 'mean', 'std']
    }).round(4)

    group_stats.columns = ['count', 'mean', 'std']
    group_stats = group_stats.reset_index()

    # Filter for groups with multiple entries
    duplicate_groups = group_stats[group_stats['count'] > 1].copy()
    # Identify single entry compounds
    single_entry_groups = group_stats[group_stats['count'] == 1].copy()

    # Initialize list for processed rows and duplicates info
    processed_rows = []
    compounds_with_dups = []

    # Process each group
    for inchi_key in group_stats['inchi_key']:
        group_data = df_work[df_work[inchi_key_col] == inchi_key].copy()
        group_stats_row = group_stats[group_stats['inchi_key'] == inchi_key].iloc[0]

        if len(group_data) > 1:  # Multiple entries
            # Add statistics to group data
            group_data['group_mean'] = group_stats_row['mean']
            group_data['group_std'] = group_stats_row['std']
            compounds_with_dups.append(group_data)

            if group_stats_row['std'] == 0:  # Zero-SD group
                # Keep only the first row for zero-SD groups
                processed_row = group_data.iloc[[0]].copy()
                processed_row['group_type'] = 'zero_sd'
            else:  # Non-zero-SD group
                # Keep first row but update pChEMBL value with mean
                processed_row = group_data.iloc[[0]].copy()
                processed_row[pchembl_col] = group_stats_row['mean']
                processed_row['group_type'] = 'nonzero_sd'

            processed_rows.append(processed_row)

        else:  # Single entry
            group_data['group_type'] = 'single_entry'
            processed_rows.append(group_data)

    # Combine all processed rows
    final_df = pd.concat(processed_rows)
    compounds_with_duplicates_df = pd.concat(compounds_with_dups) if compounds_with_dups else pd.DataFrame()

    # Create summary
    summary_stats = {
        'total_initial_compounds': len(df),
        'total_unique_inchikeys': len(group_stats),
        'single_entry_compounds': len(single_entry_groups),
        'compounds_with_duplicates': len(duplicate_groups),
        'zero_sd_groups': len(duplicate_groups[duplicate_groups['std'] == 0]),
        'nonzero_sd_groups': len(duplicate_groups[duplicate_groups['std'] > 0]),
        'final_compounds': len(final_df)
    }

    summary_df = pd.DataFrame([summary_stats]).transpose()
    summary_df.columns = ['count']

    # Sort final DataFrame by InChI key
    final_df = final_df.sort_values(by=[inchi_key_col])

    return final_df, summary_df, compounds_with_duplicates_df

# %%
final_df, summary_df, compounds_with_dups_df = process_duplicates(
    df_analyzed,
    inchi_key_col="inchi_key",
    pchembl_col="pChEMBL Value"
)

# %%
summary_df
# Out:
#                            count
# total_initial_compounds    15052
# total_unique_inchikeys      9437
# single_entry_compounds      6575
# compounds_with_duplicates   2862
# zero_sd_groups               947
# nonzero_sd_groups           1915
# final_compounds             9437

# %%
final_df.group_type.value_counts()
# Out:
# group_type
# single_entry    6575
# nonzero_sd      1915
# zero_sd          947
# Name: count, dtype: int64

# %%
nonredundant_df = final_df[["Molecule ChEMBL ID", "canonical_smiles", "inchi_key", "pChEMBL Value", "Document ChEMBL ID"]]

nonredundant_df.columns = nonredundant_df.columns.str.replace(" ", "_").str.lower()

nonredundant_df
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 2544          CHEMBL8946         CCc1cc(Cl)c(OC)c(C(=O)NC[C@@H]2CCCN2CC)c1O
# 12977      CHEMBL1256170  O=C(CCCN1CCC(c2cc3ccc2CCc2ccc(cc2)CC3)CC1)c1cc...
# 3326       CHEMBL3950977  O=C(N[C@H]1CC[C@@H](CCN2CCN(c3nsc4ccccc34)CC2)...
# 7850       CHEMBL3946995  O=C(N[C@H]1CC[C@H](CCN2CCN(c3nsc4ccccc34)CC2)C...
# 1638        CHEMBL169322         CC(C)CN1CCO[C@@H]2c3cc4c(cc3CC[C@H]21)CCO4
# ...                  ...                                                ...
# 10251      CHEMBL4571077  O=S1(=O)c2cccc3cccc(c23)N1CCCCCCN1CCN(c2ccccn2...
# 24384      CHEMBL4848710  COc1ccc2c(c1)[C@H]1OCCN(CCCCNC(=O)c3ccccc3)[C@...
# 23416      CHEMBL4759208        CN1CCN(c2ccc3ccn(S(=O)(=O)c4ccccc4)c3c2)CC1
# 9121       CHEMBL1223859  FC(F)(F)c1cccc(N2CCN(CCCCNc3nc(-c4ccccc4)cs3)C...
# 148         CHEMBL208228  CCN(Cc1ccccc1)C(=O)NCCCCN1CCN(c2cc(C(F)(F)F)nc...
#
#                          inchi_key  pchembl_value document_chembl_id
# 2544   AADCDMQTJNYOSS-LBPRGKRZSA-N         9.8633      CHEMBL3259695
# 12977  AADWBQLQKGQDIM-UHFFFAOYSA-N         7.6450      CHEMBL1255217
# 3326   AAELEHAFAYIZRH-KDURUIRLSA-N         8.7933      CHEMBL5725520
# 7850   AAELEHAFAYIZRH-WGSAOQKQSA-N         8.2075      CHEMBL3872208
# 1638   AAIDTVFHOXBFSJ-SJLPKXTDSA-N         5.3000      CHEMBL1129892
# ...                            ...            ...                ...
# 10251  ZZKFQWISNWOXAO-UHFFFAOYSA-N         6.9300      CHEMBL4387768
# 24384  ZZOGNBGGXVYUEA-IFMALSPDSA-N         6.2500      CHEMBL4823295
# 23416  ZZRPBEZGINGVMX-UHFFFAOYSA-N         6.6200      CHEMBL4732129
# 9121   ZZWMQJQCXDWUTD-UHFFFAOYSA-N         7.8900      CHEMBL1221353
# 148    ZZXVDSCUNRLYPT-UHFFFAOYSA-N         6.6700      CHEMBL1146925
#
# [9437 rows x 5 columns]

# %%
nonredundant_df.to_csv("../data/CHEMBL217_nonredundant.csv", index=False)

# %%
nonredundant_df[["pchembl_value"]].mean()
# Out:
# pchembl_value    6.752614
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Configuración de estilo
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

# Dibujar el histograma
# 'df' es vuestro DataFrame y 'pchembl_value' la columna
sns.histplot(nonredundant_df['pchembl_value'], kde=True, color="teal", bins=30)

# Añadir línea de la media (7.37)
plt.axvline(x=6.75, color='red', linestyle='--', label=f'Media: 7.37')

# Etiquetas y título
plt.title('pChEMBL values distribution', fontsize=15)
plt.xlabel('pChEMBL Value (-log10 IC50/Ki)', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.legend()

plt.show()
