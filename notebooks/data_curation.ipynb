# %%
import pandas as pd

# %%
filepath = "../data/CHEMBL1075104_raw_data.csv"
df = pd.read_csv(filepath, sep=";")
df
# Out:
# /tmp/ipykernel_8175/2023006439.py:2: DtypeWarning: Columns (0: Data Validity Comment, 1: Comment, 2: Assay Tissue ChEMBL ID, 3: Assay Tissue Name, 4: Assay Cell Type, 5: Assay Subcellular Fraction, 6: Assay Parameters, 7: Cell ChEMBL ID) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, sep=";")
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0          CHEMBL5987521           NaN                 NaN            408.76
# 1          CHEMBL5795441           NaN                 NaN            388.78
# 2          CHEMBL5782840           NaN                 NaN            337.31
# 3          CHEMBL5817783           NaN                 NaN            379.35
# 4          CHEMBL5975082           NaN                 NaN            362.24
# ...                  ...           ...                 ...               ...
# 18137      CHEMBL5877136           NaN                 NaN            393.37
# 18138      CHEMBL5957608           NaN                 NaN            390.25
# 18139      CHEMBL6038548           NaN                 NaN            427.33
# 18140      CHEMBL5753712           NaN                 NaN            407.40
# 18141      CHEMBL6009581           NaN                 NaN            400.23
#
#        #RO5 Violations  AlogP Compound Key  \
# 0                  0.0   4.35   BDBM436218
# 1                  0.0   3.48   BDBM384309
# 2                  0.0   2.56   BDBM384366
# 3                  0.0   2.26   BDBM384368
# 4                  0.0   3.21   BDBM384371
# ...                ...    ...          ...
# 18137              0.0   3.78   BDBM384408
# 18138              0.0   2.84   BDBM384409
# 18139              0.0   2.46   BDBM384410
# 18140              0.0   2.92   BDBM384382
# 18141              0.0   3.42   BDBM384387
#
#                                                   Smiles Standard Type  \
# 0      CNc1nc(Nc2cn(C3C[C@@H]4[C@H](C3)C4(F)F)nc2Cl)n...           kon
# 1          CNc1nc(Nc2cnn(C3CC4(COC4)C3)c2Cl)ncc1C(F)(F)F           kon
# 2                CCNc1nc(Nc2cnn3c2CC(C#N)C3)ncc1C(F)(F)F           kon
# 3            CCNc1nc(Nc2cnn3c2CC(n2nccn2)C3)ncc1C(F)(F)F          IC50
# 4                     CCNc1nc(Nc2cnn(C3CCC3)c2C#N)ncc1Br          IC50
# ...                                                  ...           ...
# 18137       CCNc1nc(Nc2cn(Cc3ccon3)nc2C2CC2)ncc1C(F)(F)F         k_off
# 18138           COc1nc(Nc2cn(Cc3cc[nH]n3)nc2C2CC2)ncc1Br         k_off
# 18139       CCNc1nc(Nc2cn(C3CS(=O)(=O)C3)nc2C2CC2)ncc1Br           kon
# 18140  Cn1nc(C(C)(C)n2nccn2)cc1Nc1ncc(C(F)(F)F)c(NC2C...          IC50
# 18141         Cc1nn(C(C)(C)C#N)cc1Nc1ncc(Br)c(NCC(F)F)n1          IC50
#
#       Standard Relation  ...  Document ChEMBL ID Source ID  \
# 0                   '='  ...       CHEMBL5728718        37
# 1                   '='  ...       CHEMBL5728718        37
# 2                   '='  ...       CHEMBL5726904        37
# 3                   '<'  ...       CHEMBL5726904        37
# 4                   '<'  ...       CHEMBL5726904        37
# ...                 ...  ...                 ...       ...
# 18137               '='  ...       CHEMBL5729611        37
# 18138               '='  ...       CHEMBL5729611        37
# 18139               '='  ...       CHEMBL5729611        37
# 18140               '<'  ...       CHEMBL5729611        37
# 18141               '<'  ...       CHEMBL5729611        37
#
#                       Source Description Document Journal Document Year  \
# 0      BindingDB Patent Bioactivity Data              NaN        2021.0
# 1      BindingDB Patent Bioactivity Data              NaN        2021.0
# 2      BindingDB Patent Bioactivity Data              NaN        2018.0
# 3      BindingDB Patent Bioactivity Data              NaN        2018.0
# 4      BindingDB Patent Bioactivity Data              NaN        2018.0
# ...                                  ...              ...           ...
# 18137  BindingDB Patent Bioactivity Data              NaN        2023.0
# 18138  BindingDB Patent Bioactivity Data              NaN        2023.0
# 18139  BindingDB Patent Bioactivity Data              NaN        2023.0
# 18140  BindingDB Patent Bioactivity Data              NaN        2023.0
# 18141  BindingDB Patent Bioactivity Data              NaN        2023.0
#
#       Cell ChEMBL ID  Properties  Action Type  Standard Text Value  Value
# 0                NaN         NaN          NaN                  NaN    NaN
# 1                NaN         NaN          NaN                  NaN    NaN
# 2                NaN         NaN          NaN                  NaN    NaN
# 3                NaN         NaN          NaN                  NaN   30.0
# 4                NaN         NaN          NaN                  NaN   30.0
# ...              ...         ...          ...                  ...    ...
# 18137            NaN         NaN          NaN                  NaN    NaN
# 18138            NaN         NaN          NaN                  NaN    NaN
# 18139            NaN         NaN          NaN                  NaN    NaN
# 18140            NaN         NaN          NaN                  NaN   30.0
# 18141            NaN         NaN          NaN                  NaN   30.0
#
# [18142 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties',
#        'Action Type', 'Standard Text Value', 'Value'],
#       dtype='str')

# %%
df_pchembl = df[df["pChEMBL Value"].notnull()]
df_pchembl
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 55         CHEMBL6019660           NaN                 NaN            382.42
# 57         CHEMBL6019155           NaN                 NaN            408.46
# 61         CHEMBL5938294           NaN                 NaN            387.83
# 64         CHEMBL5767996           NaN                 NaN            384.40
# 67         CHEMBL5777665           NaN                 NaN            376.40
# ...                  ...           ...                 ...               ...
# 18104      CHEMBL5915367           NaN                 NaN            392.48
# 18113      CHEMBL5915367           NaN                 NaN            392.48
# 18115      CHEMBL5865324           NaN                 NaN            399.42
# 18116      CHEMBL6055727           NaN                 NaN            416.86
# 18119      CHEMBL5995114           NaN                 NaN            396.88
#
#        #RO5 Violations  AlogP Compound Key  \
# 55                 0.0   2.22   BDBM481869
# 57                 0.0   2.76   BDBM481876
# 61                 0.0   2.84   BDBM481878
# 64                 0.0   1.59   BDBM481885
# 67                 0.0   3.06   BDBM352920
# ...                ...    ...          ...
# 18104              1.0   5.19   BDBM522423
# 18113              1.0   5.19   BDBM522423
# 18115              0.0   4.18   BDBM522435
# 18116              1.0   5.38   BDBM522411
# 18119              0.0   4.38   BDBM522414
#
#                                                   Smiles Standard Type  \
# 55        CNc1nc(Nc2ccc(C(=O)N3CCOCC3)cc2OC)nc2[nH]ccc12          IC50
# 57     COc1cc(C(=O)N2CCOCC2)ccc1Nc1nc(NC2CC2)c2cc[nH]...          IC50
# 61        COc1cc(C(=O)N2CCOCC2)ccc1Nc1ncc2c(Cl)c[nH]c2n1          IC50
# 64        COc1cc(C(=O)N2CCOCC2)ccc1Nc1nc(OC)c2cn[nH]c2n1          IC50
# 67     Fc1cc(-c2cnccn2)cc2c(-c3ccnc(N4CCOCC4)c3)n[nH]c12          IC50
# ...                                                  ...           ...
# 18104  CC1(C)CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)...          IC50
# 18113  CC1(C)CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)...          IC50
# 18115  CN1CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)C(F...          IC50
# 18116  N#CCC1CC(n2c(C3CC(F)(F)C3)nc3cnc4ccc(Cl)cc4c32...          IC50
# 18119  N#CCC1CC(n2c([C@H]3CCOC3)nc3cnc4ccc(Cl)cc4c32)...          IC50
#
#       Standard Relation  ...  Document ChEMBL ID Source ID  \
# 55                  '='  ...       CHEMBL5725226        37
# 57                  '='  ...       CHEMBL5725226        37
# 61                  '='  ...       CHEMBL5725226        37
# 64                  '='  ...       CHEMBL5725226        37
# 67                  '='  ...       CHEMBL5726581        37
# ...                 ...  ...                 ...       ...
# 18104               '='  ...       CHEMBL5728780        37
# 18113               '='  ...       CHEMBL5728780        37
# 18115               '='  ...       CHEMBL5728780        37
# 18116               '='  ...       CHEMBL5728780        37
# 18119               '='  ...       CHEMBL5728780        37
#
#                       Source Description Document Journal Document Year  \
# 55     BindingDB Patent Bioactivity Data              NaN        2021.0
# 57     BindingDB Patent Bioactivity Data              NaN        2021.0
# 61     BindingDB Patent Bioactivity Data              NaN        2021.0
# 64     BindingDB Patent Bioactivity Data              NaN        2021.0
# 67     BindingDB Patent Bioactivity Data              NaN        2017.0
# ...                                  ...              ...           ...
# 18104  BindingDB Patent Bioactivity Data              NaN        2021.0
# 18113  BindingDB Patent Bioactivity Data              NaN        2021.0
# 18115  BindingDB Patent Bioactivity Data              NaN        2021.0
# 18116  BindingDB Patent Bioactivity Data              NaN        2021.0
# 18119  BindingDB Patent Bioactivity Data              NaN        2021.0
#
#       Cell ChEMBL ID  Properties  Action Type  Standard Text Value   Value
# 55               NaN         NaN          NaN                  NaN    2.60
# 57               NaN         NaN          NaN                  NaN    2.40
# 61               NaN         NaN          NaN                  NaN  108.00
# 64               NaN         NaN          NaN                  NaN   18.50
# 67               NaN         NaN          NaN                  NaN   58.00
# ...              ...         ...          ...                  ...     ...
# 18104            NaN         NaN          NaN                  NaN    4.41
# 18113            NaN         NaN          NaN                  NaN   46.00
# 18115            NaN         NaN          NaN                  NaN   12.20
# 18116            NaN         NaN          NaN                  NaN   12.00
# 18119            NaN         NaN          NaN                  NaN    3.02
#
# [5529 rows x 48 columns]

# %%
df_pchembl[["pChEMBL Value"]]
# Out:
#        pChEMBL Value
# 55              8.59
# 57              8.62
# 61              6.97
# 64              7.73
# 67              7.24
# ...              ...
# 18104           8.36
# 18113           7.34
# 18115           7.91
# 18116           7.92
# 18119           8.52
#
# [5529 rows x 1 columns]

# %%
df[df["Target Organism"] == "Homo sapiens"]
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0          CHEMBL5987521           NaN                 NaN            408.76
# 1          CHEMBL5795441           NaN                 NaN            388.78
# 2          CHEMBL5782840           NaN                 NaN            337.31
# 3          CHEMBL5817783           NaN                 NaN            379.35
# 4          CHEMBL5975082           NaN                 NaN            362.24
# ...                  ...           ...                 ...               ...
# 18137      CHEMBL5877136           NaN                 NaN            393.37
# 18138      CHEMBL5957608           NaN                 NaN            390.25
# 18139      CHEMBL6038548           NaN                 NaN            427.33
# 18140      CHEMBL5753712           NaN                 NaN            407.40
# 18141      CHEMBL6009581           NaN                 NaN            400.23
#
#        #RO5 Violations  AlogP Compound Key  \
# 0                  0.0   4.35   BDBM436218
# 1                  0.0   3.48   BDBM384309
# 2                  0.0   2.56   BDBM384366
# 3                  0.0   2.26   BDBM384368
# 4                  0.0   3.21   BDBM384371
# ...                ...    ...          ...
# 18137              0.0   3.78   BDBM384408
# 18138              0.0   2.84   BDBM384409
# 18139              0.0   2.46   BDBM384410
# 18140              0.0   2.92   BDBM384382
# 18141              0.0   3.42   BDBM384387
#
#                                                   Smiles Standard Type  \
# 0      CNc1nc(Nc2cn(C3C[C@@H]4[C@H](C3)C4(F)F)nc2Cl)n...           kon
# 1          CNc1nc(Nc2cnn(C3CC4(COC4)C3)c2Cl)ncc1C(F)(F)F           kon
# 2                CCNc1nc(Nc2cnn3c2CC(C#N)C3)ncc1C(F)(F)F           kon
# 3            CCNc1nc(Nc2cnn3c2CC(n2nccn2)C3)ncc1C(F)(F)F          IC50
# 4                     CCNc1nc(Nc2cnn(C3CCC3)c2C#N)ncc1Br          IC50
# ...                                                  ...           ...
# 18137       CCNc1nc(Nc2cn(Cc3ccon3)nc2C2CC2)ncc1C(F)(F)F         k_off
# 18138           COc1nc(Nc2cn(Cc3cc[nH]n3)nc2C2CC2)ncc1Br         k_off
# 18139       CCNc1nc(Nc2cn(C3CS(=O)(=O)C3)nc2C2CC2)ncc1Br           kon
# 18140  Cn1nc(C(C)(C)n2nccn2)cc1Nc1ncc(C(F)(F)F)c(NC2C...          IC50
# 18141         Cc1nn(C(C)(C)C#N)cc1Nc1ncc(Br)c(NCC(F)F)n1          IC50
#
#       Standard Relation  ...  Document ChEMBL ID Source ID  \
# 0                   '='  ...       CHEMBL5728718        37
# 1                   '='  ...       CHEMBL5728718        37
# 2                   '='  ...       CHEMBL5726904        37
# 3                   '<'  ...       CHEMBL5726904        37
# 4                   '<'  ...       CHEMBL5726904        37
# ...                 ...  ...                 ...       ...
# 18137               '='  ...       CHEMBL5729611        37
# 18138               '='  ...       CHEMBL5729611        37
# 18139               '='  ...       CHEMBL5729611        37
# 18140               '<'  ...       CHEMBL5729611        37
# 18141               '<'  ...       CHEMBL5729611        37
#
#                       Source Description Document Journal Document Year  \
# 0      BindingDB Patent Bioactivity Data              NaN        2021.0
# 1      BindingDB Patent Bioactivity Data              NaN        2021.0
# 2      BindingDB Patent Bioactivity Data              NaN        2018.0
# 3      BindingDB Patent Bioactivity Data              NaN        2018.0
# 4      BindingDB Patent Bioactivity Data              NaN        2018.0
# ...                                  ...              ...           ...
# 18137  BindingDB Patent Bioactivity Data              NaN        2023.0
# 18138  BindingDB Patent Bioactivity Data              NaN        2023.0
# 18139  BindingDB Patent Bioactivity Data              NaN        2023.0
# 18140  BindingDB Patent Bioactivity Data              NaN        2023.0
# 18141  BindingDB Patent Bioactivity Data              NaN        2023.0
#
#       Cell ChEMBL ID  Properties  Action Type  Standard Text Value  Value
# 0                NaN         NaN          NaN                  NaN    NaN
# 1                NaN         NaN          NaN                  NaN    NaN
# 2                NaN         NaN          NaN                  NaN    NaN
# 3                NaN         NaN          NaN                  NaN   30.0
# 4                NaN         NaN          NaN                  NaN   30.0
# ...              ...         ...          ...                  ...    ...
# 18137            NaN         NaN          NaN                  NaN    NaN
# 18138            NaN         NaN          NaN                  NaN    NaN
# 18139            NaN         NaN          NaN                  NaN    NaN
# 18140            NaN         NaN          NaN                  NaN   30.0
# 18141            NaN         NaN          NaN                  NaN   30.0
#
# [18142 rows x 48 columns]

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import PandasTools

def identify_duplicates(df, smiles_column):
    def standardize_smiles(smiles):
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return None
            return Chem.MolToSmiles(mol, canonical=True)
        except:
            return None

    def calculate_inchi_key(smiles):
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return None
            return Chem.MolToInchiKey(mol)
        except:
            return None

    df_analysis = df.copy()
    df_analysis["canonical_smiles"] = df_analysis[smiles_column].apply(standardize_smiles)
    df_analysis["inchi_key"] = df_analysis["canonical_smiles"].apply(calculate_inchi_key)
    df_analysis["is_valid"] = df_analysis["canonical_smiles"].notna()
    df_analysis["is_duplicate"] = df_analysis["inchi_key"].duplicated(keep="first")
    df_analysis["duplicate_group"] = df_analysis.groupby("inchi_key").ngroup()
    duplicate_counts = df_analysis["inchi_key"].value_counts()
    df_analysis["occurrence_count"] = df_analysis["inchi_key"].map(duplicate_counts)

    return df_analysis

def get_duplicate_summary(df_analysis):
    summary = {
        "total_molecules": len(df_analysis),
        "invalid_smiles": (~df_analysis["is_valid"]).sum(),
        "unique_molecules": df_analysis["inchi_key"].nunique(),
        "duplicate_molecules": df_analysis["is_duplicate"].sum(),
        "molecules_with_duplicates": len(df_analysis[df_analysis["occurrence_count"] > 1]),
        "max_duplicates": df_analysis["occurrence_count"].max()
    }
    return summary

# %%
df_analyzed = identify_duplicates(df_pchembl, "Smiles")
df_analyzed
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 55         CHEMBL6019660           NaN                 NaN            382.42
# 57         CHEMBL6019155           NaN                 NaN            408.46
# 61         CHEMBL5938294           NaN                 NaN            387.83
# 64         CHEMBL5767996           NaN                 NaN            384.40
# 67         CHEMBL5777665           NaN                 NaN            376.40
# ...                  ...           ...                 ...               ...
# 18104      CHEMBL5915367           NaN                 NaN            392.48
# 18113      CHEMBL5915367           NaN                 NaN            392.48
# 18115      CHEMBL5865324           NaN                 NaN            399.42
# 18116      CHEMBL6055727           NaN                 NaN            416.86
# 18119      CHEMBL5995114           NaN                 NaN            396.88
#
#        #RO5 Violations  AlogP Compound Key  \
# 55                 0.0   2.22   BDBM481869
# 57                 0.0   2.76   BDBM481876
# 61                 0.0   2.84   BDBM481878
# 64                 0.0   1.59   BDBM481885
# 67                 0.0   3.06   BDBM352920
# ...                ...    ...          ...
# 18104              1.0   5.19   BDBM522423
# 18113              1.0   5.19   BDBM522423
# 18115              0.0   4.18   BDBM522435
# 18116              1.0   5.38   BDBM522411
# 18119              0.0   4.38   BDBM522414
#
#                                                   Smiles Standard Type  \
# 55        CNc1nc(Nc2ccc(C(=O)N3CCOCC3)cc2OC)nc2[nH]ccc12          IC50
# 57     COc1cc(C(=O)N2CCOCC2)ccc1Nc1nc(NC2CC2)c2cc[nH]...          IC50
# 61        COc1cc(C(=O)N2CCOCC2)ccc1Nc1ncc2c(Cl)c[nH]c2n1          IC50
# 64        COc1cc(C(=O)N2CCOCC2)ccc1Nc1nc(OC)c2cn[nH]c2n1          IC50
# 67     Fc1cc(-c2cnccn2)cc2c(-c3ccnc(N4CCOCC4)c3)n[nH]c12          IC50
# ...                                                  ...           ...
# 18104  CC1(C)CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)...          IC50
# 18113  CC1(C)CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)...          IC50
# 18115  CN1CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)C(F...          IC50
# 18116  N#CCC1CC(n2c(C3CC(F)(F)C3)nc3cnc4ccc(Cl)cc4c32...          IC50
# 18119  N#CCC1CC(n2c([C@H]3CCOC3)nc3cnc4ccc(Cl)cc4c32)...          IC50
#
#       Standard Relation  ...  Properties Action Type  Standard Text Value  \
# 55                  '='  ...         NaN         NaN                  NaN
# 57                  '='  ...         NaN         NaN                  NaN
# 61                  '='  ...         NaN         NaN                  NaN
# 64                  '='  ...         NaN         NaN                  NaN
# 67                  '='  ...         NaN         NaN                  NaN
# ...                 ...  ...         ...         ...                  ...
# 18104               '='  ...         NaN         NaN                  NaN
# 18113               '='  ...         NaN         NaN                  NaN
# 18115               '='  ...         NaN         NaN                  NaN
# 18116               '='  ...         NaN         NaN                  NaN
# 18119               '='  ...         NaN         NaN                  NaN
#
#         Value                                   canonical_smiles  \
# 55       2.60     CNc1nc(Nc2ccc(C(=O)N3CCOCC3)cc2OC)nc2[nH]ccc12
# 57       2.40  COc1cc(C(=O)N2CCOCC2)ccc1Nc1nc(NC2CC2)c2cc[nH]...
# 61     108.00     COc1cc(C(=O)N2CCOCC2)ccc1Nc1ncc2c(Cl)c[nH]c2n1
# 64      18.50     COc1cc(C(=O)N2CCOCC2)ccc1Nc1nc(OC)c2cn[nH]c2n1
# 67      58.00  Fc1cc(-c2cnccn2)cc2c(-c3ccnc(N4CCOCC4)c3)n[nH]c12
# ...       ...                                                ...
# 18104    4.41  CC1(C)CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)...
# 18113   46.00  CC1(C)CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)...
# 18115   12.20  CN1CC(n2c(C3CCC(F)C3)nc3cnc4ccc(C#N)cc4c32)C(F...
# 18116   12.00  N#CCC1CC(n2c(C3CC(F)(F)C3)nc3cnc4ccc(Cl)cc4c32...
# 18119    3.02  N#CCC1CC(n2c([C@H]3CCOC3)nc3cnc4ccc(Cl)cc4c32)...
#
#                          inchi_key  is_valid  is_duplicate  duplicate_group  \
# 55     OJICYHVVYWJPEY-UHFFFAOYSA-N      True         False           1864.0
# 57     JZSOJGCVLKPLMA-UHFFFAOYSA-N      True         False           1271.0
# 61     KYTQJRZAHZFVJM-UHFFFAOYSA-N      True         False           1421.0
# 64     QHEKEKAYQOLOAA-UHFFFAOYSA-N      True         False           2161.0
# 67     KPSFRLNGSIYUCK-UHFFFAOYSA-N      True         False           1367.0
# ...                            ...       ...           ...              ...
# 18104  YZPHYZVOZXGFQJ-UHFFFAOYSA-N      True          True           3275.0
# 18113  YZPHYZVOZXGFQJ-UHFFFAOYSA-N      True          True           3275.0
# 18115  IMXLFVISBPYHPR-UHFFFAOYSA-N      True          True           1088.0
# 18116  QWGYZWSTLWLTCH-UHFFFAOYSA-N      True          True           2247.0
# 18119  AHQPJCUEBFHSCN-JEYLPNPQSA-N      True          True             49.0
#
#        occurrence_count
# 55                  4.0
# 57                  2.0
# 61                  2.0
# 64                  2.0
# 67                  1.0
# ...                 ...
# 18104              10.0
# 18113              10.0
# 18115              10.0
# 18116               2.0
# 18119               2.0
#
# [5529 rows x 54 columns]

# %%
summary = get_duplicate_summary(df_analyzed)
summary
# Out:
# {'total_molecules': 5529,
#  'invalid_smiles': np.int64(1),
#  'unique_molecules': 3421,
#  'duplicate_molecules': np.int64(2107),
#  'molecules_with_duplicates': 3394,
#  'max_duplicates': np.float64(32.0)}

# %%
import pandas as pd
import numpy as np

def process_duplicates(df, inchi_key_col, pchembl_col):
    """Process duplicates with different handling for zero-SD and non-zero-SD groups."""
    # Create working copy
    df_work = df.copy()

    # Calculate group statistics
    group_stats = df_work.groupby(inchi_key_col).agg({
        pchembl_col: ['count', 'mean', 'std']
    }).round(4)

    group_stats.columns = ['count', 'mean', 'std']
    group_stats = group_stats.reset_index()

    # Filter for groups with multiple entries
    duplicate_groups = group_stats[group_stats['count'] > 1].copy()
    # Identify single entry compounds
    single_entry_groups = group_stats[group_stats['count'] == 1].copy()

    # Initialize list for processed rows and duplicates info
    processed_rows = []
    compounds_with_dups = []

    # Process each group
    for inchi_key in group_stats['inchi_key']:
        group_data = df_work[df_work[inchi_key_col] == inchi_key].copy()
        group_stats_row = group_stats[group_stats['inchi_key'] == inchi_key].iloc[0]

        if len(group_data) > 1:  # Multiple entries
            # Add statistics to group data
            group_data['group_mean'] = group_stats_row['mean']
            group_data['group_std'] = group_stats_row['std']
            compounds_with_dups.append(group_data)

            if group_stats_row['std'] == 0:  # Zero-SD group
                # Keep only the first row for zero-SD groups
                processed_row = group_data.iloc[[0]].copy()
                processed_row['group_type'] = 'zero_sd'
            else:  # Non-zero-SD group
                # Keep first row but update pChEMBL value with mean
                processed_row = group_data.iloc[[0]].copy()
                processed_row[pchembl_col] = group_stats_row['mean']
                processed_row['group_type'] = 'nonzero_sd'

            processed_rows.append(processed_row)

        else:  # Single entry
            group_data['group_type'] = 'single_entry'
            processed_rows.append(group_data)

    # Combine all processed rows
    final_df = pd.concat(processed_rows)
    compounds_with_duplicates_df = pd.concat(compounds_with_dups) if compounds_with_dups else pd.DataFrame()

    # Create summary
    summary_stats = {
        'total_initial_compounds': len(df),
        'total_unique_inchikeys': len(group_stats),
        'single_entry_compounds': len(single_entry_groups),
        'compounds_with_duplicates': len(duplicate_groups),
        'zero_sd_groups': len(duplicate_groups[duplicate_groups['std'] == 0]),
        'nonzero_sd_groups': len(duplicate_groups[duplicate_groups['std'] > 0]),
        'final_compounds': len(final_df)
    }

    summary_df = pd.DataFrame([summary_stats]).transpose()
    summary_df.columns = ['count']

    # Sort final DataFrame by InChI key
    final_df = final_df.sort_values(by=[inchi_key_col])

    return final_df, summary_df, compounds_with_duplicates_df

# %%
final_df, summary_df, compounds_with_dups_df = process_duplicates(
    df_analyzed,
    inchi_key_col="inchi_key",
    pchembl_col="pChEMBL Value"
)

# %%
summary_df
# Out:
#                            count
# total_initial_compounds     5529
# total_unique_inchikeys      3421
# single_entry_compounds      2134
# compounds_with_duplicates   1287
# zero_sd_groups               143
# nonzero_sd_groups           1144
# final_compounds             3421

# %%
final_df.group_type.value_counts()
# Out:
# group_type
# single_entry    2134
# nonzero_sd      1144
# zero_sd          143
# Name: count, dtype: int64

# %%
nonredundant_df = final_df[["Molecule ChEMBL ID", "canonical_smiles", "inchi_key", "pChEMBL Value", "Document ChEMBL ID"]]

nonredundant_df.columns = nonredundant_df.columns.str.replace(" ", "_").str.lower()

nonredundant_df
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 8780       CHEMBL4067228               O=C(Nc1cccnc1)c1cc(Cl)ccc1OCc1ccccc1
# 2941       CHEMBL3643956  CNc1nc(Nc2ccc(C(=O)N3CCOCC3)cc2OC2CCC2)ncc1C(F...
# 11567      CHEMBL3651762                  COc1cc(-c2n[nH]c3ccnc(OC)c23)ccn1
# 10070          CHEMBL553         C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1
# 336        CHEMBL5859679  Cc1ccc2[nH]cc(C)c2c1-c1ccc2nc(NC(=O)[C@@H]3C[C...
# ...                  ...                                                ...
# 1696       CHEMBL3894116       CC(C)=Cc1ccc2[nH]nc(-c3cc(N4CCOCC4)ncn3)c2c1
# 2389       CHEMBL3979676                 COc1cccc(-c2ccnc3[nH]cc(C#N)c23)c1
# 15711      CHEMBL6036028      Cn1nc(C(=O)Nc2ccc3[nH]nc(-c4ccoc4)c3c2)cc1C#N
# 12664      CHEMBL6022113   Cc1cc(-n2ncc3ccc([C@]4(C#N)CC45CC5)cc32)nc(CO)n1
# 2918       CHEMBL3970173  COC1CCN(c2cc(-c3n[nH]c4ccc(-c5cnn(C)c5)cc34)nc...
#
#                          inchi_key  pchembl_value document_chembl_id
# 8780   AAACBXVBBDAYRQ-UHFFFAOYSA-N           7.80      CHEMBL4052807
# 2941   AAFQGUVMCRNVEK-UHFFFAOYSA-N           8.60      CHEMBL3639246
# 11567  AAJWREVOQDWFCD-UHFFFAOYSA-N           7.10      CHEMBL3638634
# 10070  AAKJLRGGTJKAMG-UHFFFAOYSA-N           5.43      CHEMBL1908390
# 336    AAQFTGFEIOSNMG-CABCVRRESA-N           6.76      CHEMBL5728679
# ...                            ...            ...                ...
# 1696   ZYSDPOYDLQCQDX-UHFFFAOYSA-N           7.79      CHEMBL3886204
# 2389   ZZDGQQQSEKEUFO-UHFFFAOYSA-N           6.94      CHEMBL4028875
# 15711  ZZLNBYJMDVKCIB-UHFFFAOYSA-N           6.26      CHEMBL5729282
# 12664  ZZMRPAQHMTYJJX-LJQANCHMSA-N           9.20      CHEMBL5728785
# 2918   ZZRDOQNASJKWCE-UHFFFAOYSA-N           8.69      CHEMBL3886204
#
# [3421 rows x 5 columns]

# %%
nonredundant_df.to_csv("../data/CHEMBL1075104_nonredundant.csv", index=False)

# %%
nonredundant_df[["pchembl_value"]].mean()
# Out:
# pchembl_value    7.375073
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Configuración de estilo
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

# Dibujar el histograma
# 'df' es vuestro DataFrame y 'pchembl_value' la columna
sns.histplot(nonredundant_df['pchembl_value'], kde=True, color="teal", bins=30)

# Añadir línea de la media (7.37)
plt.axvline(x=7.37, color='red', linestyle='--', label=f'Media: 7.37')

# Etiquetas y título
plt.title('pChEMBL values distribution for LRRK2 (n=3421)', fontsize=15)
plt.xlabel('pChEMBL Value (-log10 IC50/Ki)', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.legend()

plt.show()
